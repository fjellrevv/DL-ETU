# %%
! pip install ultralytics --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 811.0 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.1/869.1 kB 12.2 MB/s eta 0:00:00

# %%
# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="pXLrXQVgneXGX2CJpBeR")
project = rf.workspace("roboflow-universe-projects").project("fire-and-smoke-segmentation")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.8 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.79, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Fire-and-Smoke-Segmentation-4 in yolov8:: 100%|██████████| 414/414 [00:00<00:00, 7120.77it/s]

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 53.5MB/s]

# %%
model.train(data="/content/yolo_project/datasets/data.yaml", epochs=100,
            patience=0, plots=True, project='/content/yolo_project')
# Out:
# Ultralytics YOLOv8.2.79 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from IPython.display import Image

# %%
Image('/content/yolo_project/train/results.png')

# %%
Image('/content/yolo_project/train/F1_curve.png')

# %%
Image('/content/yolo_project/train/val_batch0_labels.jpg')

# %%
Image('/content/yolo_project/train/val_batch0_pred.jpg')

# %%
model.load('/content/yolo_project/train/weights/best.pt')
# Out:
# Transferred 355/355 items from pretrained weights
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.2.79 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/yolo_project/datasets/Fire-and-Smoke-Segmentation-4/valid/labels.cache... 40 images, 0 backgrounds, 0 corrupt: 100%|██████████| 40/40 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:11<00:00,  3.98s/it]
#                    all         40         97      0.797      0.682      0.747      0.524
#                   fire         40         58      0.905      0.825      0.891      0.671
#                  smoke         28         39      0.689      0.538      0.604      0.377
# Speed: 4.5ms preprocess, 283.3ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /content/yolo_project/train2

# %%
source = 'http://lirp.cdn-website.com/f5a91db6/dms3rep/multi/opt/causes-of-house-fires-restoration-1-of-lake-charles-1920w.jpg'
result = model.predict(source, save=True)
# Out:
# ...
# 100%|██████████| 84.8k/84.8k [00:00<00:00, 764kB/s]
# image 1/1 /content/causes-of-house-fires-restoration-1-of-lake-charles-1920w.jpg: 448x640 3 fires, 1 smoke, 162.2ms
# Speed: 4.1ms preprocess, 162.2ms inference, 4.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/yolo_project/train3

# %%
Image('/content/yolo_project/train3/causes-of-house-fires-restoration-1-of-lake-charles-1920w.jpg')
